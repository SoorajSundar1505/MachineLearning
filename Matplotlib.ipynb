# %% [markdown]
# <a href="https://colab.research.google.com/github/SoorajSundar1505/MachineLearning/blob/master/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import matplotlib

import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
z = np.cos(x)
print(x)
print(y)
print(z)

# %%
#plotting the data
#sine wave

plt.plot(x,y)
plt.show()

# %%
#build cos
plt.plot(x,z)
plt.show()

# %%
#adding title, x and y axis label

plt.plot(x,y)
plt.xlabel('angle')
plt.ylabel('sine')
plt.title('Sine Wave')
plt.show()
